# %%
import boto3
import json
import configparser
import psycopg2
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
conn_string="postgresql://awsuser:Boody_147@redshift-cluster-1.cqg9qzlhb5uz.us-east-1.redshift.amazonaws.com:5439/dev"
print(conn_string)
# %sql $conn_string
# Out:
# postgresql://awsuser:Boody_147@redshift-cluster-1.cqg9qzlhb5uz.us-east-1.redshift.amazonaws.com:5439/dev
# 'Connected: awsuser@dev'

# %%
conn = psycopg2.connect("host=redshift-cluster-1.cqg9qzlhb5uz.us-east-1.redshift.amazonaws.com dbname=dev user=awsuser password=Boody_147 port=5439")
conn.set_session(autocommit=True)
cur = conn.cursor()

# %%
KEY='AKIA4SCDZVLATAI27BUP'
SECRET='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'

# %%
import boto3

s3 = boto3.resource('s3',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                     )

sampleDbBucket =  s3.Bucket("udacity-dend")
i = 0
for obj in sampleDbBucket.objects.filter(Prefix='song_data'):
     print(obj)
# Out:
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAAK128F9318786.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAAV128F421A322.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAABD128F429CF47.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAACN128F9355673.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAEA128F935A30D.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAED128E0783FAB.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAEM128F93347B9.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAEW128F42930C0.json')
# s3.ObjectSummary(bucket_name='udacity-dend', key='song_data/A/A/A/TRAAAFD128F92F423A.json')
# ...

# %%
file = sampleDbBucket.download_file(Filename= 'log.json',Key='log_data/2018/11/2018-11-17-events.json',)

# %%
with open('song.json','r') as f:
    print(f.read())
# Out:
# {"artist_id":"AR1C2IX1187B99BF74","artist_latitude":null,"artist_location":"","artist_longitude":null,"artist_name":"Broken Spindles","duration":177.99791,"num_songs":1,"song_id":"SODZYPO12A8C13A91E","title":"Burn My Body (Album Version)","year":0}

# %%
with open('log.json','r') as f:
    print(f.read().split('}')[2] )
# Out:
# {"artist":"Placebo","auth":"Logged In","firstName":"Chloe","gender":"F","itemInSession":55,"lastName":"Cuevas","length":224.02567,"level":"paid","location":"San Francisco-Oakland-Hayward, CA","method":"PUT","page":"NextSong","registration":1540940782796.0,"sessionId":648,"song":"Breathe Underwater","status":200,"ts":1542413451796,"userAgent":"Mozilla\/5.0 (Windows NT 5.1; rv:31.0) Gecko\/20100101 Firefox\/31.0","userId":"49"

# %%
cur.execute('DROP TABLE IF EXISTS "staging_events";')
cur.execute('DROP TABLE IF EXISTS "staging_songs";')

# %%
cur.execute('''
CREATE TABLE "staging_songs"(
    "artist_id"           VARCHAR,
    "artist_latitude"     VARCHAR,
    "artist_location"     VARCHAR,
    "artist_longitude"    VARCHAR,
    "artist_name"         VARCHAR,
    "duration"            DECIMAL,
    "num_songs"           INT,
    "song_id"             VARCHAR,
    "title"               VARCHAR,
    "year"                INT
);
''')
cur.execute('''
CREATE TABLE "staging_events"(
    "artist"           VARCHAR,
    "auth"             VARCHAR,
    "firstName"        VARCHAR,
    "gender"           VARCHAR,
    "itemInSession"    INT,
    "lastName"         VARCHAR,
    "length"           FLOAT,
    "level"            VARCHAR,
    "location"         VARCHAR,
    "method"           VARCHAR,
    "page"             VARCHAR,
    "registration"     TIMESTAMP,
    "sessionId"        INT,
    "song"             VARCHAR,
    "status"           INT,
    "ts"               TIMESTAMP,
    "userAgent"        VARCHAR,
    "userId"           INT
    
);
''')

# %%
ARN='arn:aws:iam::863430617793:role/myRedshiftRole'

# %%
qry = """
    copy staging_events from 's3://udacity-dend/log_data/2018/'
    credentials 'aws_iam_role={}'
    region 'us-west-2'
    FORMAT AS JSON 'auto'
    TIMEFORMAT AS 'epochmillisecs';
""".format(ARN)

# %sql $qry
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.cqg9qzlhb5uz.us-east-1.redshift.amazonaws.com:5439/dev
# Done.
# []

# %%
qry = """
    copy staging_songs from 's3://udacity-dend/song_data/A/'
    credentials 'aws_iam_role={}'
    region 'us-west-2'
    FORMAT AS JSON 'auto'
    TIMEFORMAT AS 'epochmillisecs';
""".format(ARN)

# %sql $qry
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.cqg9qzlhb5uz.us-east-1.redshift.amazonaws.com:5439/dev

# %% [markdown]
# ## Create Tables

# %%
cur.execute('DROP TABLE IF EXISTS "songplays";')
cur.execute('DROP TABLE IF EXISTS "users";')
cur.execute('DROP TABLE IF EXISTS "songs";')
cur.execute('DROP TABLE IF EXISTS "artists";')
cur.execute('DROP TABLE IF EXISTS "time";')

# %%
cur.execute('''
CREATE TABLE  "users" (
    "user_id"     INT PRIMARY KEY,
    "first_name"  VARCHAR,
    "last_name"   VARCHAR,
    "gender"      VARCHAR,
    "level"       VARCHAR
);
''')

cur.execute('''
CREATE TABLE "songs" (
    "song_id"    VARCHAR PRIMARY KEY,
    "title"      VARCHAR,
    "artist_id"  VARCHAR,
    "year"       INT,
    "duration"   DECIMAL
);
''')



cur.execute('''
CREATE TABLE "artists"(
    "artist_id"     VARCHAR PRIMARY KEY,
    "name"          VARCHAR,
    "location"      VARCHAR,
    "longitude"     VARCHAR,
    "latitude"      VARCHAR
);
''')

cur.execute('''
CREATE TABLE "time"(
    "start_time"    TIMESTAMP PRIMARY KEY, 
    "hour"          INT, 
    "day"           INT, 
    "week"          INT, 
    "month"         INT,        
    "year"          INT, 
    "weekday"       INT
);
''')

cur.execute('''
CREATE TABLE "songplays"(
    "songplay_id" INT IDENTITY(0,1),
    "start_time"  TIMESTAMP, 
    "user_id"     INT, 
    "level"       VARCHAR, 
    "song_id"     VARCHAR, 
    "artist_id"   VARCHAR,
    "session_id"  INT, 
    "location"    VARCHAR, 
    "user_agent"  VARCHAR,
    FOREIGN KEY ("start_time") REFERENCES "time" ("start_time"),
    FOREIGN KEY ("user_id")    REFERENCES "users" ("user_id"),
    FOREIGN KEY ("song_id")    REFERENCES "songs" ("song_id"),
    FOREIGN KEY ("artist_id")  REFERENCES "artists" ("artist_id")
);
''')

# %%
# %%sql
# SELECT * FROM staging_songs LIMIT 1;
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.cqg9qzlhb5uz.us-east-1.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [('ARDJRZJ1187B99BBAF', None, '', None, 'Marine Girls', Decimal('147'), 1, 'SOXCOHE12A58A79969', 'Shell Island', 1983)]

# %%
cur.execute('''
INSERT INTO songplays (start_time, user_id, level, song_id, artist_id, session_id, location, user_agent)
SELECT e.ts, e.userId, e.level, s.song_id, s.artist_id, e.sessionId, e.location, e.userAgent 
FROM staging_songs    AS      s 
JOIN staging_events   AS      e 
ON e.song = s.title  
WHERE e.page = 'NextSong'; 
''')

cur.execute('''
INSERT INTO users (user_id, first_name, last_name, gender, level)
SELECT e.userid, e.firstname, e.lastname, e.gender, e.level
FROM staging_events    AS      e 
WHERE e.userid IS NOT NULL AND e.page = 'NextSong';
''')


cur.execute('''
INSERT INTO songs (song_id, title, artist_id, year, duration)
SELECT s.song_id, s.title, s.artist_id, s.year, s.duration 
FROM staging_songs    AS      s; 
''')

cur.execute('''
INSERT INTO artists (artist_id, name, location, longitude, latitude)
SELECT s.artist_id, e.artist, s.artist_location, s.artist_longitude,s.artist_latitude
FROM staging_events    AS      e
JOIN staging_songs     AS      s
ON e.song = s.title
WHERE e.page = 'NextSong'; 
''')


cur.execute('''
INSERT INTO time (start_time, hour, day, week, month, year, weekday)
SELECT DISTINCT(ts), EXTRACT(hour FROM ts), EXTRACT(day FROM ts), EXTRACT(week FROM ts), EXTRACT(month FROM ts), EXTRACT(year FROM ts), EXTRACT(weekday FROM ts)
FROM staging_events;
''')

# %%
# %%sql
# SELECT s.*
# FROM songplays s
# Out:
#  * postgresql://awsuser:***@redshift-cluster-1.cqg9qzlhb5uz.us-east-1.redshift.amazonaws.com:5439/dev
# 1 rows affected.
# [(0, datetime.datetime(2018, 11, 16, 14, 21, 12, 796000), None, 'paid', 'SOLRYQR12A670215BF', 'ARNLO5S1187B9B80CC', None, 'Red Bluff, CA', None)]
